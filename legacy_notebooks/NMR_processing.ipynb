# %%
import os
import sys
import numpy as np
import pandas as pd
# %load_ext autoreload
# %autoreload 2
from toolsets.search import string_search, quick_search_values
from toolsets.NMR_tools import nmr_processing, nmr_stack, readin_nmr_profile, calculate_explained_area, nmr_head_to_tail, nmr_plot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # define master directories

# %%
nmr_fractions_dir = '/Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica/nmr_data'# this is the nmr_data
nmr_std_dir = '/Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica/nmr_lib'#nmr_lib

# %%
nico_smoothed, nico_raw = readin_nmr_profile('STD002583.csv', nmr_std_dir)
fraction_smoothed, fraction_raw = readin_nmr_profile('1090_X4.csv', nmr_fractions_dir)
astra_smoothed, astra_raw = readin_nmr_profile('STD002579.csv', nmr_std_dir)
# cluster_statistics, simulated_std, model_cluster_statistics = nmr_processing(nico_smoothed, fraction_smoothed)
isoq_smoothed, isoq_raw = readin_nmr_profile('STD002587.csv', nmr_std_dir)
# simulated_all[conc]=simulated_std
# (calculate_explained_area(cluster_statistics))

# %% [markdown]
# # plto nmr

# %%
nmr_plot(nico_smoothed,
         cs_start=3, cs_end=3.2)

# %%
cluster_statistics, simulated_std, model_cluster_statistics = nmr_processing(astra_smoothed, fraction_smoothed)
# first one is always ur stadnard, second one is fraction
(calculate_explained_area(cluster_statistics))
# Out:
# 0.794819010984477

# %%
model_cluster_statistics
# Out:
#       ratio  peak_id  peak_apex   intensity      area  peak_start  peak_end  \
# 0  0.757928     1062   3.793775  911.712136  4.914267    3.784429  3.796250
# 1  0.630035     1063   3.800100  999.948489  8.795827    3.796250  3.822556
#
#    peak_length_half  peak_length_full  cluster_id  ...  split     score  \
# 0          0.005255          0.011821           0  ...      2  0.543464
# 1          0.006543          0.026306           0  ...      2  0.543464
#
#    fraction_peak_id  fraction_peak_apex  fraction_intensity  fraction_area  \
# 0            1052.0             3.81495           691.01221       3.453909
# 1            1053.0             3.81880           630.00233       4.584858
#
#    fraction_peak_start  fraction_peak_end  fraction_peak_length_half  \
# 0              3.81110            3.81715                    0.00605
# 1              3.81715            3.82595                    0.00880
#
#    fraction_peak_length_full
# 0                    0.00605
# ...

# %%
cluster_statistics
# Out:
#     peak_id  peak_apex   intensity      area  peak_start  peak_end  \
# 0      1062   3.793775  911.712136  4.914267    3.784429  3.796250
# 1      1063   3.800100  999.948489  8.795827    3.796250  3.822556
# 3       312   0.820200  333.147208  2.985889    0.806626  0.827625
# 4       313   0.838350  505.071188  3.233996    0.827625  0.838625
# 5       314   0.840000  507.813690  3.982214    0.838625  0.850725
# ..      ...        ...         ...       ...         ...       ...
# 91      471   1.594325   13.996727  0.096662    1.588000  1.595425
# 90      470   1.586625   12.114164  0.019824    1.586350  1.588000
# 89      469   1.585525   12.195393  0.061358    1.581125  1.586350
# 98      478   1.614125   14.939437  0.056029    1.611925  1.615775
# 43     3305   8.545225   46.941053  0.549545    8.531814  8.567775
#
#     peak_length_half  peak_length_full  cluster_id     shift      corr  split  \
# 0           0.005255          0.011821           0  0.021175  0.575535      2
# ...

# %%
nmr_stack(fraction_smoothed, simulated_std, cs_start=3.72,cs_end=3.85,
          shift2=0.021175
          )

# %%
cluster_statistics, simulated_std, model_cluster_statistics = nmr_processing(isoq_smoothed, fraction_smoothed, force_cluster = )
# simulated_all[conc]=simulated_std
(calculate_explained_area(cluster_statistics))
# Out:
# 0.9958765666466799

# %%
nmr_std_dir
# Out:
# '/Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica/nmr_lib'

# %%
cluster_statistics
# Out:
#      peak_id  peak_apex   intensity      area  peak_start  peak_end  \
# 3       2102   6.167300    6.842286  0.018014    6.164550  6.167850
# 4       2103   6.183250  297.471675  1.851128    6.170906  6.185725
# 5       2104   6.188200  291.207483  1.661317    6.185725  6.199001
# 9       2869   7.715000  261.864744  1.596635    7.712800  7.729509
# 8       2868   7.710050  280.158199  1.702584    7.699254  7.712800
# ..       ...        ...         ...       ...         ...       ...
# 398     1338   4.687250   10.233696  0.023558    4.685875  4.688350
# 399     1339   4.690550   11.333201  0.038603    4.688350  4.692200
# 400     1340   4.693575    9.761217  0.036653    4.692200  4.696050
# 608     2436   6.897975    6.338491  0.012429    6.896600  6.898800
# 609     2437   6.899900    6.298095  0.013376    6.898800  6.901000
#
#      peak_length_half  peak_length_full  cluster_id    shift      corr  split  \
# ...

# %%
cluster_statistics.to_csv(os.path.join(nmr_std_dir, 'result_iso_q.csv'))

# %%
nmr_stack(fraction_smoothed, simulated_std
          , cs_start=2.5,cs_end=3
          )

# %%
cluster_statistics
# Out:
#      peak_id  peak_apex   intensity      area  peak_start  peak_end  \
# 5       2117   7.710875  255.983638  1.683980    7.699783  7.713625
# 6       2118   7.715550  246.275023  1.637726    7.713625  7.731850
# 2       1558   6.188475  273.043246  1.692988    6.186550  6.200310
# 1       1557   6.184350  273.209665  1.832256    6.171346  6.186550
# 9        951   5.240825  185.549603  1.678892    5.226633  5.249900
# ..       ...        ...         ...       ...         ...       ...
# 296      371   2.158350    7.785898  0.028186    2.156975  2.160825
# 306      114   0.825150    6.878519  0.013006    0.824600  0.826525
# 307      115   0.827625    6.923480  0.023069    0.826525  0.830100
# 283      344   2.043675    8.365377  0.009160    2.043400  2.044500
# 282      343   2.042575    8.400112  0.013773    2.041750  2.043400
#
#      peak_length_half  peak_length_full  cluster_id     shift      corr  \
# 5            0.005874          0.013842           3 -0.000550  0.898131
# ...

# %%
cluster_statistics, simulated_std, model_cluster_statistics = nmr_processing(nico_smoothed, fraction_smoothed)
# simulated_all[conc]=simulated_std
(calculate_explained_area(cluster_statistics))
# Out:
# 0.9594063766118667

# %%
cluster_statistics
# Out:
#      peak_id  peak_apex   intensity      area  peak_start  peak_end  \
# 5       2117   7.710875  255.983638  1.683980    7.699783  7.713625
# 6       2118   7.715550  246.275023  1.637726    7.713625  7.731850
# 1       1557   6.184350  273.209665  1.832256    6.171346  6.186550
# 2       1558   6.188475  273.043246  1.692988    6.186550  6.200310
# 9        951   5.240825  185.549603  1.678892    5.226633  5.249900
# ..       ...        ...         ...       ...         ...       ...
# 190      130   0.871075   10.705052  0.032086    0.869150  0.872175
# 184      124   0.856775   10.506791  0.030174    0.854300  0.857325
# 185      125   0.858700   10.738171  0.044805    0.857325  0.861725
# 186      126   0.863375    9.971496  0.026814    0.861725  0.864475
# 189      129   0.868600   10.470942  0.014302    0.867775  0.869150
#
#      peak_length_half  peak_length_full  cluster_id     shift      corr  \
# 5            0.005874          0.013842           3 -0.000550  0.898131
# ...

# %%
result_dir = '/Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica/results'

# %%
nmr_stack(fraction_smoothed, simulated_std,
          # cs_start=1.1, cs_end=1.14, shift2=0.00110
          save_path=os.path.join(result_dir, 'nico_full.png')
          )

# %%
nmr_stack(fraction_smoothed, simulated_std,
          cs_start=1.1, cs_end=1.14, shift2=0.00110,
          save_path=os.path.join(result_dir, 'nico_zoomed.png')
          )

# %%
nico_smoothed, nico_raw = readin_nmr_profile('STD002583.csv', nmr_std_dir)
fraction_smoothed, fraction_raw = readin_nmr_profile('1090_X3.csv', nmr_fractions_dir)
cate_smoothed, cate_raw = readin_nmr_profile('STD002572.csv', nmr_std_dir)

# %%
cluster_statistics, simulated_std, model_cluster_statistics = nmr_processing(nico_smoothed, fraction_smoothed)
# simulated_all[conc]=simulated_std
(calculate_explained_area(cluster_statistics))
# Out:
# 0.9594063766118667

# %%
cluster_statistics
# Out:
#     peak_id  peak_apex      intensity         area  peak_start  peak_end  \
# 0       151   1.115275  885821.600016  7400.804431    1.098775  1.122700
# 1       152   1.130675  881855.184833  6781.662498    1.122700  1.142572
# 10     1290   6.214050  413074.492676  2076.451433    6.206238  6.216525
# 11     1291   6.219000  438341.747141  2304.293083    6.216525  6.227872
# 14     1373   6.410400  407279.655220  2182.026242    6.402419  6.413150
# ..      ...        ...            ...          ...         ...       ...
# 23      626   3.256150  260930.762909  3686.462508    3.239925  3.264400
# 12      822   4.517575  422253.515365  4343.159636    4.506008  4.528850
# 9       628   3.299875  453865.185883  1731.941348    3.289150  3.300136
# 8       627   3.280625  376547.144220  4847.598014    3.264400  3.289150
# 30      680   3.806700   41110.892519    78.946022    3.806150  3.808075
#
#     peak_length_half  peak_length_full  cluster_id    shift      corr  split  \
# ...

# %%
cluster_statistics, simulated_std, model_cluster_statistics = nmr_processing(cate_smoothed, fraction_smoothed)
# simulated_all[conc]=simulated_std
(calculate_explained_area(cluster_statistics))
# Out:
# 0.8988876966632962

# %%
nmr_stack(fraction_smoothed, simulated_std, cs_start=4.5, cs_end=4.6)

# %%
cluster_statistics
# Out:
#      peak_id  peak_apex      intensity         area  peak_start  peak_end  \
# 0        151   1.115275  885821.600016  7400.804431    1.098775  1.122700
# 1        152   1.130675  881855.184833  6781.662498    1.122700  1.142572
# 10      1290   6.214050  413074.492676  2076.451433    6.206238  6.216525
# 11      1291   6.219000  438341.747141  2304.293083    6.216525  6.227872
# 28       878   5.163000   11327.019813    99.720915    5.158875  5.172350
# ..       ...        ...            ...          ...         ...       ...
# 122      620   3.188500   14042.914555    26.924423    3.187950  3.189875
# 123      621   3.192350   14386.616988    38.978148    3.189875  3.192625
# 124      622   3.196750   15429.866683   127.842666    3.192625  3.201150
# 125      623   3.205825   16837.722533    83.135039    3.201150  3.206375
# 315      400   2.272750    9240.271431    73.724501    2.271925  2.281000
#
#      peak_length_half  peak_length_full  cluster_id     shift      corr  \
# ...

# %%
nmr_stack(fraction_smoothed, simulated_std, cs_start=1.1, cs_end=1.15)

# %%
cluster_statistics
# Out:
#      peak_id  peak_apex      intensity         area  peak_start  peak_end  \
# 0        151   1.115275  885821.600016  7400.804431    1.098775  1.122700
# 1        152   1.130675  881855.184833  6781.662498    1.122700  1.142572
# 10      1290   6.214050  413074.492676  2076.451433    6.206238  6.216525
# 11      1291   6.219000  438341.747141  2304.293083    6.216525  6.227872
# 14      1373   6.410400  407279.655220  2182.026242    6.402419  6.413150
# ..       ...        ...            ...          ...         ...       ...
# 310      220   1.511275    9034.861942    17.309482    1.511000  1.512925
# 311      221   1.516500    9501.412570    50.949993    1.512925  1.518425
# 132      135   0.982175   16411.190344    35.896999    0.981625  0.983825
# 133      136   0.984375   16161.744185    13.328597    0.983825  0.984650
# 53      2197   8.353275   29882.032462   244.122081    8.343100  8.364000
#
#      peak_length_half  peak_length_full  cluster_id     shift      corr  \
# ...

# %%
from toolsets.search import string_search

# %%
top_cluster = string_search(cluster_statistics, 'cluster_id', 7)

# %%
len(top_cluster[top_cluster['area']>0.8*top_cluster['area'].max()])
# Out:
# 1

# %%
np.sqrt(5)
# Out:
# 2.23606797749979

# %%
from toolsets.search import quick_search_values

# %%
quick_search_values(cluster_statistics, 'peak_apex', 1.1, 1.14, ifsorted=False)
# Out:
#    peak_id  peak_apex      intensity         area  peak_start  peak_end  \
# 0      151   1.115275  885821.600016  7400.804431    1.098775  1.122700
# 1      152   1.130675  881855.184833  6781.662498    1.122700  1.142572
#
#    peak_length_half  peak_length_full  cluster_id   shift      corr  split  \
# 0          0.006286          0.023925           0  0.0011  0.793313      2
# 1          0.006143          0.019872           0  0.0011  0.793313      2
#
#       score  simulated_area  matched
# 0  0.919595       32.093221    False
# 1  0.919595       29.408343    False

# %%
1.115275-1.130675
# Out:
# -0.01540000000000008

# %%
# from toolsets.setup import set_workspace, get_dirs
# master_dir = '/Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica'
#
# set_workspace(master_dir)
# # this is the master workspace, all other directories will be created within this workspace
# dirs =get_dirs(master_dir, mode='pos')
# Out:
# the workspace exists!
# set up complete
# at position 0:  /Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica/alignment_result/pos
# at position 1:  /Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica/bioactivity
# at position 2:  /Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica/mzml/pos
# at position 3:  /Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica/normalized_peak_list/pos
# at position 4:  /Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica/peak_list/pos
# at position 5:  /Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica/results/pos
# at position 6:  /Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica/sirius_files/pos
# at position 7:  /Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica/uv_data
# at position 8:  /Volumes/Natural Product Chemistry/Working Space/Fanzhou/Myristica/nmr_data
# ...

# %%
# nmr_library_dir = dirs[11]
# nmr_sample_dir = dirs[8]
nmr_dir_spi = '/Volumes/Natural Product Chemistry/Working Space/Fanzhou/legacy/20230824_NMR_Spike_Exp_standardized'
nmr_dir_reverse = '/Volumes/Natural Product Chemistry/Working Space/Fanzhou/legacy/20230829_NMR_Reverse_Spike'

# %%
lut_smoothed, lut_raw = readin_nmr_profile('Luteolin_1_profile.csv', nmr_dir_spi)
ribose_smoothed, ribose_raw = readin_nmr_profile('Ribose_1_profile.csv', nmr_dir_spi)
re_spi_conc = [0, 25, 50, 75, 100]

# %%
from tqdm import tqdm

# %%
concs = [5,1,0.5, 0.1,0.05, 0.01, 0.005,0]
calculated = []
rp_smoothed_all = {}
simulated_all = {}
model_clusters = {}
for conc in (concs):
    file_name = 'Spike_'+str(conc)+'_profile.csv'
    # print(file_name)
    rp_smoothed, rp_raw = readin_nmr_profile(file_name, nmr_dir_spi)
    rp_smoothed_all[conc]=rp_smoothed
    cluster_statistics, simulated_std, model_cluster_statistics = nmr_processing(ribose_smoothed, rp_smoothed)
    simulated_all[conc]=simulated_std
    model_clusters[conc]=cluster_statistics
    calculated.append(calculate_explained_area(cluster_statistics))
    print(calculate_explained_area(cluster_statistics))
# print(calculated)
# Out:
# 0.9873454879049763
# 0.9920808587293182
# 0.9920808587293182
# 0.9747459842009476
# 0.9747459842009476
# 0.9747459842009476
# 0.9747459842009476
# 0.9920808587293182

# %%
model_clusters[5]
# Out:
#     peak_id  peak_apex     intensity       area  peak_start  peak_end  \
# 2       940   3.911750   1381.111608   7.156733    3.902950  3.914500
# 3       941   3.917800   2415.695642  11.088928    3.914500  3.921650
# 4       942   3.923850   1144.100726   4.998884    3.921650  3.929596
# 1       939   3.900200    220.865546   1.174524    3.896075  3.902950
# 12      933   3.850975   1292.153490   6.245132    3.848500  3.854550
# 13      934   3.855375    672.950010   2.457094    3.854550  3.861700
# 10      931   3.827875   1511.715573   7.388550    3.825125  3.834750
# 11      932   3.844650   1692.002492  12.184560    3.834750  3.848500
# 22      873   3.446175   1060.022509   5.441054    3.439407  3.448925
# 23      874   3.453875   1357.186499  10.765834    3.448925  3.458825
# 24      875   3.462675   1288.766588   7.136476    3.458825  3.467900
# 25      876   3.470925    491.433874   2.040486    3.467900  3.476947
# ...

# %%
model_clusters[0]
# Out:
#     peak_id  peak_apex     intensity       area  peak_start  peak_end  \
# 2       940   3.911750   1381.111608   7.156733    3.902950  3.914500
# 3       941   3.917800   2415.695642  11.088928    3.914500  3.921650
# 4       942   3.923850   1144.100726   4.998884    3.921650  3.929596
# 1       939   3.900200    220.865546   1.174524    3.896075  3.902950
# 23      874   3.453875   1357.186499  10.765834    3.448925  3.458825
# 22      873   3.446175   1060.022509   5.441054    3.439407  3.448925
# 24      875   3.462675   1288.766588   7.136476    3.458825  3.467900
# 25      876   3.470925    491.433874   2.040486    3.467900  3.476947
# 13      934   3.855375    672.950010   2.457094    3.854550  3.861700
# 12      933   3.850975   1292.153490   6.245132    3.848500  3.854550
# 11      932   3.844650   1692.002492  12.184560    3.834750  3.848500
# 10      931   3.827875   1511.715573   7.388550    3.825125  3.834750
# ...

# %%
nmr_stack(rp_smoothed_all[5],simulated_all[5],
         cs_start=3.88, cs_end=3.95)

# %%
model_clusters[1]
# Out:
#     peak_id  peak_apex     intensity       area  peak_start  peak_end  \
# 18      915   3.747025    665.278120   4.035280    3.744000  3.754450
# 14      911   3.721175    745.539926   3.920228    3.714172  3.723100
# 17      914   3.740700   1037.470041   5.450491    3.737125  3.744000
# 16      913   3.734100   1069.224055   5.221908    3.730800  3.737125
# 15      912   3.727225   1524.550798   8.467440    3.723100  3.730800
# 1       939   3.900200    220.865546   1.174524    3.896075  3.902950
# 3       941   3.917800   2415.695642  11.088928    3.914500  3.921650
# 4       942   3.923850   1144.100726   4.998884    3.921650  3.929596
# 2       940   3.911750   1381.111608   7.156733    3.902950  3.914500
# 25      876   3.470925    491.433874   2.040486    3.467900  3.476947
# 24      875   3.462675   1288.766588   7.136476    3.458825  3.467900
# 23      874   3.453875   1357.186499  10.765834    3.448925  3.458825
# ...

# %%
calculated = []
rp_smoothed_all = {}
simulated_all = {}
model_clusters = {}
for conc in tqdm(re_spi_conc):
    file_name = 'Spike_'+str(conc)+'_profile.csv'
    # print(file_name)
    rp_smoothed, rp_raw = readin_nmr_profile(file_name, nmr_dir_reverse)
    rp_smoothed_all[conc]=rp_smoothed
    cluster_statistics, simulated_std, model_cluster_statistics = nmr_processing(ribose_smoothed, rp_smoothed)
    simulated_all[conc]=simulated_std
    model_clusters[conc]=cluster_statistics
    calculated.append(calculate_explained_area(cluster_statistics))
print(calculated)
    # break
    # break
# Out:
# 100%|██████████| 5/5 [00:31<00:00,  6.22s/it]
# [0.9808371434011292, 0.9952646291756582, 0.9952646291756582, 0.9952646291756582, 0.9952646291756582]

# %%
quick_search_values(model_clusters[0], 'peak_apex', value_start=3.9, value_end=3.94, ifsorted=False)
# Out:
#    peak_id  peak_apex    intensity       area  peak_start  peak_end  \
# 1      939    3.90020   220.865546   1.174524    3.896075  3.902950
# 2      940    3.91175  1381.111608   7.156733    3.902950  3.914500
# 3      941    3.91780  2415.695642  11.088928    3.914500  3.921650
# 4      942    3.92385  1144.100726   4.998884    3.921650  3.929596
#
#    peak_length_half  peak_length_full  cluster_id     shift      corr  split  \
# 1          0.006875          0.006875           1  0.000275  0.996607      3
# 2          0.004840          0.011550           1  0.000275  0.996607      3
# 3          0.004463          0.007150           1  0.000275  0.996607      3
# 4          0.004487          0.007946           1  0.000275  0.996607      3
#
#       score  simulated_area  simulated_intensity  matched
# 1  0.496847        0.992407           186.618878     True
# 2  0.496847        6.047034          1166.961091     True
# 3  0.496847        9.369516          2041.126007     True
# ...

# %%
model_cluster_statistics
# Out:
#       ratio  peak_id  peak_apex    intensity       area  peak_start  peak_end  \
# 0  0.203127      931   3.827875  1511.715573   7.388550    3.825125   3.83475
# 1  0.193493      932   3.844650  1692.002492  12.184560    3.834750   3.84850
# 2  0.258821      933   3.850975  1292.153490   6.245132    3.848500   3.85455
# 3  0.496971      934   3.855375   672.950010   2.457094    3.854550   3.86170
#
#    peak_length_half  peak_length_full  cluster_id  ...  split     score  \
# 0          0.005163          0.009625           3  ...      3  0.425267
# 1          0.007746          0.013750           3  ...      3  0.425267
# 2          0.006050          0.006050           3  ...      3  0.425267
# 3          0.003316          0.007150           3  ...      3  0.425267
#
#    fraction_peak_id  fraction_peak_apex  fraction_intensity  fraction_area  \
# 0            1356.0            3.830900          307.069672       1.900651
# ...

# %%
200*1.4
# Out:
# 280.0

# %%
nmr_plot(ribose_smoothed, cs_start=3.6, cs_end=3.67)

# %%
nmr_stack(rp_smoothed_all[0], simulated_all[0], cs_start=4.581925-0.05,cs_end=4.581925+0.05,)

# %%
nmr_stack(rp_smoothed, simulated_std, cs_start=3.9,cs_end=3.94,)

# %%
np.log10(11.088928)*np.log10(3)*0.832335

# %%
quick_search_values(cluster_statistics, 'peak_apex', value_start=3.9, value_end=3.94, ifsorted=False)
# Out:
#    peak_id  peak_apex    intensity       area  peak_start  peak_end  \
# 1      939    3.90020   220.865546   1.174524    3.896075  3.902950
# 2      940    3.91175  1381.111608   7.156733    3.902950  3.914500
# 3      941    3.91780  2415.695642  11.088928    3.914500  3.921650
# 4      942    3.92385  1144.100726   4.998884    3.921650  3.929596
#
#    peak_length_half  peak_length_full  cluster_id     shift      corr  split  \
# 1          0.006875          0.006875           1  0.006325  0.832335      3
# 2          0.004840          0.011550           1  0.006325  0.832335      3
# 3          0.004463          0.007150           1  0.006325  0.832335      3
# 4          0.004487          0.007946           1  0.006325  0.832335      3
#
#    score  simulated_area  simulated_intensity  matched
# 1    0.0        0.303949            57.156690     True
# 2    0.0        1.852055           357.410963     True
# 3    0.0        2.869648           625.145789    False
# ...

# %%
4.99888/11
# Out:
# 0.4544436363636363

# %%
nmr_stack(rp_smoothed_all[50],simulated_all[50],
          cs_start=3.9,cs_end=3.94,
          vline_location_upper=[3.917800,
                                3.923850
                                ])

# %%
cluster_statistics
# Out:
#     peak_id  peak_apex     intensity       area  peak_start  peak_end  \
# 18      875   3.462675   1288.766588   7.136476    3.458825  3.467900
# 16      873   3.446175   1060.022509   5.441054    3.439407  3.448925
# 17      874   3.453875   1357.186499  10.765834    3.448925  3.458825
# 2       941   3.917800   2415.695642  11.088928    3.914500  3.921650
# 3       942   3.923850   1144.100726   4.998884    3.921650  3.929596
# 1       940   3.911750   1381.111608   7.156733    3.902950  3.914500
# 4       904   3.666725    446.231007   1.945548    3.663700  3.668925
# 5       905   3.671950   2195.180479   9.343633    3.668925  3.677725
# 6       906   3.680475    457.477883   2.595116    3.677725  3.684875
# 10      911   3.721175    745.539926   3.920228    3.714172  3.723100
# 11      912   3.727225   1524.550798   8.467440    3.723100  3.730800
# 12      913   3.734100   1069.224055   5.221908    3.730800  3.737125
# ...

# %%
calculated
# Out:
# [0.9306897194101321,
#  0.9761017725767874,
#  0.964150063384646,
#  0.9952646291756582,
#  0.9952646291756582]

# %%
calculated
# Out:
# [0.9934388905101686,
#  0.9934388905101686,
#  0.9934388905101686,
#  0.9934388905101686,
#  0.9934388905101686]

# %%
cluster_statistics
# Out:
#     peak_id  peak_apex     intensity        area  peak_start  peak_end  \
# 5      1554   6.208000   3499.572292   11.110953    6.204781  6.210475
# 6      1555   6.212125   3684.056732   12.740031    6.210475  6.216704
# 9      1949   7.397100   2162.918577    7.925786    7.392425  7.400125
# 10     1950   7.401500   1402.164045    4.832378    7.400125  7.406748
# 3      1634   6.442300   3753.877963   11.941452    6.438769  6.444775
# 4      1635   6.446425   3728.385447   12.625655    6.444775  6.451028
# 0       631   2.658850  62707.768226  192.444781    2.656233  2.662583
# 1      1948   7.381700   8199.604451   38.527349    7.376097  7.387476
# 2      1658   6.545975   7232.118401   25.240342    6.542398  6.550410
# 8      1792   6.898525   2469.562471   12.160874    6.892297  6.903931
# 7      1793   6.914475   2740.581026   12.984978    6.909179  6.920680
# 12      448   1.934500    687.258751    2.281889    1.931159  1.938672
# ...

# %%
nmr_plot(rp_smoothed,
         cs_start=1.9,cs_end=1.95)

# %%
nmr_stack(rp_smoothed,simulated_std,
         cs_start=6,cs_end=7.5)

# %%
# Spike_100_profile.csv

# %% [markdown]
# # initial readin

# %%
ref_smoothed, ref_raw = readin_nmr_profile('Luteolin_1_profile.csv', nmr_dir)
sample_smoothed, sample_raw =  readin_nmr_profile('Spike_1_profile.csv', nmr_dir)

# %%
nmr_head_to_tail(sample_smoothed, ref_smoothed)

# %% [markdown]
# # nmr spectra - make matches

# %%
cluster_statistics, simulated_std, model_cluster_statistics = nmr_processing(ref_smoothed, sample_smoothed)
calculate_explained_area(cluster_statistics)
# Out:
# 1.0

# %%
cluster_statistics
# Out:
#     peak_id  peak_apex     intensity        area  peak_start  peak_end  \
# 5      1554   6.208000   3499.572292   11.110953    6.204781  6.210475
# 6      1555   6.212125   3684.056732   12.740031    6.210475  6.216704
# 3      1634   6.442300   3753.877963   11.941452    6.438769  6.444775
# 4      1635   6.446425   3728.385447   12.625655    6.444775  6.451028
# 9      1949   7.397100   2162.918577    7.925786    7.392425  7.400125
# 10     1950   7.401500   1402.164045    4.832378    7.400125  7.406748
# 0       631   2.658850  62707.768226  192.444781    2.656233  2.662583
# 1      1948   7.381700   8199.604451   38.527349    7.376097  7.387476
# 7      1793   6.914475   2740.581026   12.984978    6.909179  6.920680
# 8      1792   6.898525   2469.562471   12.160874    6.892297  6.903931
# 2      1658   6.545975   7232.118401   25.240342    6.542398  6.550410
# 11      830   3.299875    838.755992    2.973609    3.288906  3.300136
# ...

# %%
# cluster_statistics: key statistics for all clusters found in reference standard spectra
# simulated_std: simulated signal for standard
# key statistics for model peaks

# %%
nmr_stack(sample_smoothed,simulated_std,
          # cs_start=6, cs_end=7.5,
          # shift2=0.012925,
          # save_path=os.path.join(figure_dir, 'lut_spike5_zoomed_6to7.5.png')
          )

# %%
nmr_stack(sample_smoothed,simulated_std,
          cs_start=6, cs_end=7.5,
          # shift2=0.012925,
          # save_path=os.path.join(figure_dir, 'lut_spike5_zoomed_6to7.5.png')
          )
# cs_start/cs_end: zoom in options
# shift2: position shift, please use the shift number in matching_results[0], if you are using this option please have the simulated signal as second argument
# save_path: if you want to save the figure
